# %%
import base64

# %%
with open("../img/geza.jpg", "rb") as image_file:
    byt = base64.b64encode(image_file.read())

# %%
im = byt.decode()

# %%
with open("../img/geza.jpg", "wb") as fh:
    fh.write(base64.encodebytes(img_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a912fdca59e8> in <module>
#       1 with open("../img/geza.jpg", "wb") as fh:
# ----> 2     fh.write(base64.encodebytes(img_data))
#
# NameError: name 'img_data' is not defined

# %%
im
# Out:
# '...'

# %%
with open('bin.bin', "wb") as f:
    f.write(im)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-bba24c9e5bc9> in <module>
#       1 with open('bin.bin', "wb") as f:
# ----> 2     f.write(im)
#
# TypeError: a bytes-like object is required, not 'str'

# %%
with open('geza.jpg', 'wb') as file_to_save:
    decoded_image_data = base64.encodebytes(file_to_save)
    file_to_save.write(decoded_image_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/envs/stck/lib/python3.7/base64.py in _input_type_check(s)
#     509     try:
# --> 510         m = memoryview(s)
#     511     except TypeError as err:
#
# TypeError: memoryview: a bytes-like object is required, not '_io.BufferedWriter'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-25f8cb924e08> in <module>
#       1 with open('geza.jpg', 'wb') as file_to_save:
# ----> 2     decoded_image_data = base64.encodebytes(file_to_save)
#       3     file_to_save.write(decoded_image_data)
#
# ~/miniconda3/envs/stck/lib/python3.7/base64.py in encodebytes(s)
#     525     """Encode a bytestring into a bytes object containing multiple lines
#     526     of base-64 data."""
# ...

# %%
with open("geza.jpg", "rb") as image_file:
    byt = base64.b64encode(image_file.read())

# %%
byt
# Out:
# b''

# %%
import talib
import pandas as pd

# %%
df = pd.read_csv("../data/boston.csv")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
